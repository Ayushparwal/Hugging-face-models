# %% [markdown]
# ## Creating the Image from text using the pretrained models

# %% [markdown]
# link: https://huggingface.co/black-forest-labs/FLUX.1-dev

# %%
from huggingface_hub import InferenceClient
client = InferenceClient("black-forest-labs/FLUX.1-dev", token="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")

image = client.text_to_image("Astronaut riding a horse")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>

# %%
image = client.text_to_image("a man eating fish and taking a selfie")

# %%
image
